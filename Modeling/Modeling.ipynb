# %%
import pandas as pd
import numpy as np
order_item_df = pd.read_csv(r'D:\Datamamagemet\python\source\bikestore_dim\staging_2\order_item\order_item.csv')
order_df = pd.read_csv(r'D:\Datamamagemet\python\source\bikestore_dim\staging_2\order\order.csv')
product_df = pd.read_csv(r'D:\Datamamagemet\python\source\bikestore_dim\staging_2\products\products.csv')

# %%
order_item_product = pd.merge(order_item_df, product_df, on='product_id')
orders_products_details=pd.merge(order_df,order_item_product,on='order_id')
orders_products_details.head()
# Out:
#    order_id  customer_id  order_status  order_date required_date shipped_date  \
# 0         1          259             4  2016-01-01    2016-01-03   2016-01-03
# 1         1          259             4  2016-01-01    2016-01-03   2016-01-03
# 2         1          259             4  2016-01-01    2016-01-03   2016-01-03
# 3         1          259             4  2016-01-01    2016-01-03   2016-01-03
# 4         1          259             4  2016-01-01    2016-01-03   2016-01-03
#
#    store_id  staff_id  extract_time source  ...  source_x  USD_to_EGP  \
# 0         1         2  1.714410e+09     DB  ...        DB        47.9
# 1         1         2  1.714410e+09     DB  ...        DB        47.9
# 2         1         2  1.714410e+09     DB  ...        DB        47.9
# 3         1         2  1.714410e+09     DB  ...        DB        47.9
# 4         1         2  1.714410e+09     DB  ...        DB        47.9
#
# ...

# %%
import os
output_dir = r'D:\Datamamagemet\python\source\bikestore_dim\Information Mart'

os.makedirs(output_dir, exist_ok=True)

orders_products_details.to_csv(os.path.join(output_dir, 'orders_products_details.csv'), index=False)
